# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - Requests & CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^100^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': '5c6dae83-a281-4e49-9c41-581e01368a43',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4697.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7,ar;q=0.6',
    'cookie': 'client_guid_timestamp=57cdfdd4-b54d-4de2-b54a-fbc9f4ccc7b7.1636501342398; scavenger-a493=...; _gid=GA1.2.1413140232.1636501343; sp-nuid=b12a080f-ecb9-4fe0-9bdc-d5c87645bf98; _gcl_au=1.1.1400066687.1636501349; _fbp=fb.1.1636540347795.876027232; ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzEwMC4wLjQ2OTcuMCBTYWZhcmkvNTM3LjM2In0=; _sp_ses.8ca5=*; _ga_152345333=GS1.1.1636638826.2.1.1636638849.0; AMP_TOKEN=^%^24NOT_FOUND; _ga=GA1.2.659824584.1636501343; cto_bundle=cQGHG19HaHolMkZLc3p2aEN2cDRaNzN5JTJGU21aM0hndnRkemxvNTA5VzdtUGNPbU1pUHZzcGZFVHptWjAlMkJDY2xBdWFwODRXa1FYeFdlWXczalRpaTFoNTd6eTQlMkZsdlVNdUwlMkI4cE56VG10N2Ixa0s3NlVWam9USiUyQlIyQnhaUnNHenBOTVA2YlVDakhxTURVVnQ2VmZFZ2N2UEJGZHclM0QlM0Q; _sp_id.8ca5=4c19c5a3-4e70-4727-8336-a0f2c5fcb7ae.1636501343.4.1636641025.1636578697.5724cbb4-37af-443c-a22c-26362577d75b',
    'if-none-match': 'W/^\\^b863d05a1913cbe8d162cdce62ebbf0d^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'New^%%5E20York,^%%5E20NY'),
    ('latitude', '40.7127753'),
    ('longitude', '-74.0059728'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
response.json()
# Out:
# {'total_results_count': 358,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2022,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1631750481,
#    'recent_price_drop': False,
#    'is_hot': True,
#    'href_target': '/listings/5YJSA1H1XEFP36459',
#    'vdp_url': '/tesla-model+s#vin=5YJSA1H1XEFP36459',
#    'clickoff_url': '',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 227609628,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/09/18/02/43/2014_tesla_model_s-pic-2987450451533545082-1024x768.jpeg',
# ...

# %%
type(response.json())
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
response.json().keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Finding Data

# %%
response.json()['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1631750481,
#   'recent_price_drop': False,
#   'is_hot': True,
#   'href_target': '/listings/5YJSA1H1XEFP36459',
#   'vdp_url': '/tesla-model+s#vin=5YJSA1H1XEFP36459',
#   'clickoff_url': '',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 227609628,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/09/18/02/43/2014_tesla_model_s-pic-2987450451533545082-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ipqZLQDU--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/09/18/02/43/2014_tesla_model_s-pic-2987450451533545082-1024x768.jpeg',
#   'lat': 40.8847,
#   'lon': -73.8315,
#   'year': 2014,
#   'make': 'Tesla',
#   'model': 'Model S',
#   'model_id': 2006,
#   'display_color': '',
#   'price': '$33,950',
#   'price_unformatted': 33950,
#   'mileage': '56,461 Miles',
#   'mileage_unformatted': 56461,
#   'city': 'Bronx',
# ...

# %%
len(response.json()['search_results'])
# Out:
# 20

# %%
results_json = response.json()['search_results']

# %%
#name aka make
#model
#year
#price
#mileage
#city
#state
#dealer_name

# %%
results_json[0]['make']
# Out:
# 'Tesla'

# %%
results_json[0]['model']
# Out:
# 'Model S'

# %%
results_json[0]['year']
# Out:
# 2014

# %%
results_json[0]['price']
# Out:
# '$33,950'

# %%
results_json[0]['mileage']
# Out:
# '56,461 Miles'

# %%
results_json[0]['city']
# Out:
# 'Bronx'

# %%
results_json[0]['state']
# Out:
# 'NY'

# %%
results_json[0]['dealer_name']
# Out:
# '26 Motors'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
name= []
model= []
year= []
price= []
mileage= []
city= []
state= []
dealer_name= []
for result in results_json:
    name.append(result['make'])
    model.append(result['model'])
    year.append(result['year'])
    price.append(result['price'])
    mileage.append(result['mileage'])
    city.append(result['city'])
    state.append(result['state'])
    dealer_name.append(result['dealer_name'])

# %%
len(name)
# Out:
# 20

# %%
model
# Out:
# ['Model S',
#  'Model S',
#  'Model X',
#  'Model 3',
#  'Model S',
#  'Model Y',
#  'Model S',
#  'Model 3',
#  'Model S',
#  'Model 3',
#  'Model S',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model 3',
#  'Model S',
#  'Model 3',
#  'Model 3']

# %%
price
# Out:
# ['$33,950',
#  '$42,900',
#  '$84,295',
#  '$40,905',
#  '$56,995',
#  '$74,990',
#  '$35,995',
#  '$47,505',
#  '$82,995',
#  '$54,800',
#  '$153,999',
#  '$59,505',
#  '$45,995',
#  '$49,990',
#  '$51,995',
#  '$51,995',
#  '$50,905',
#  '$79,800',
#  '$52,990',
#  '$51,000']

# %%
mileage
# Out:
# ['56,461 Miles',
#  '66,843 Miles',
#  '20,046 Miles',
#  '9,437 Miles',
#  '29,710 Miles',
#  '1,450 Miles',
#  '51,951 Miles',
#  '10,302 Miles',
#  '27,706 Miles',
#  '23,710 Miles',
#  '202 Miles',
#  '11,997 Miles',
#  '25,085 Miles',
#  '43,337 Miles',
#  '11,358 Miles',
#  '19,298 Miles',
#  '40,537 Miles',
#  '13,172 Miles',
#  '7,529 Miles',
#  '12,451 Miles']

# %%
city
# Out:
# ['Bronx',
#  'Somerville',
#  'White Plains',
#  'Elizabeth',
#  'Totowa',
#  'Somerville',
#  'Wall Township',
#  'Ocean',
#  'Wall Township',
#  'Linden',
#  'Riverdale',
#  'Ocean',
#  'Edison',
#  'Somerville',
#  'Greenvale',
#  'White Plains',
#  'Elizabeth',
#  'White Plains',
#  'Princeton',
#  'Jersey City']

# %% [markdown]
# #### Step 8 - Pandas Dataframe

# %%
cars_df= pd.DataFrame({'Name':name,'Model':model,'Year':year,'City':city,'State':state,'Dealer_name':dealer_name,'Mileage':mileage,'Price':price})

# %%
cars_df
# Out:
#      Name    Model  Year           City State  \
# 0   Tesla  Model S  2014          Bronx    NY
# 1   Tesla  Model S  2014     Somerville    NJ
# 2   Tesla  Model X  2018   White Plains    NY
# 3   Tesla  Model 3  2020      Elizabeth    NJ
# 4   Tesla  Model S  2017         Totowa    NJ
# 5   Tesla  Model Y  2021     Somerville    NJ
# 6   Tesla  Model S  2014  Wall Township    NJ
# 7   Tesla  Model 3  2019          Ocean    NJ
# 8   Tesla  Model S  2018  Wall Township    NJ
# 9   Tesla  Model 3  2020         Linden    NJ
# 10  Tesla  Model S  2021      Riverdale    NJ
# 11  Tesla  Model 3  2020          Ocean    NJ
# 12  Tesla  Model 3  2018         Edison    NJ
# 13  Tesla  Model 3  2018     Somerville    NJ
# 14  Tesla  Model 3  2018      Greenvale    NY
# 15  Tesla  Model 3  2018   White Plains    NY
# 16  Tesla  Model 3  2019      Elizabeth    NJ
# 17  Tesla  Model S  2018   White Plains    NY
# 18  Tesla  Model 3  2021      Princeton    NJ
# ...

# %% [markdown]
# #### Step 9 - Dataframe to excel

# %%
cars_df.to_excel('teslaCars.xlsx',index=False)

# %% [markdown]
# #### Step 10 - Scraping Multiple pages

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^100^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': '5c6dae83-a281-4e49-9c41-581e01368a43',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4697.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7,ar;q=0.6',
    'cookie': 'client_guid_timestamp=57cdfdd4-b54d-4de2-b54a-fbc9f4ccc7b7.1636501342398; scavenger-a493=...; _gid=GA1.2.1413140232.1636501343; sp-nuid=b12a080f-ecb9-4fe0-9bdc-d5c87645bf98; _gcl_au=1.1.1400066687.1636501349; _fbp=fb.1.1636540347795.876027232; ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzEwMC4wLjQ2OTcuMCBTYWZhcmkvNTM3LjM2In0=; _sp_ses.8ca5=*; _ga_152345333=GS1.1.1636638826.2.1.1636638849.0; AMP_TOKEN=^%^24NOT_FOUND; _ga=GA1.2.659824584.1636501343; cto_bundle=cQGHG19HaHolMkZLc3p2aEN2cDRaNzN5JTJGU21aM0hndnRkemxvNTA5VzdtUGNPbU1pUHZzcGZFVHptWjAlMkJDY2xBdWFwODRXa1FYeFdlWXczalRpaTFoNTd6eTQlMkZsdlVNdUwlMkI4cE56VG10N2Ixa0s3NlVWam9USiUyQlIyQnhaUnNHenBOTVA2YlVDakhxTURVVnQ2VmZFZ2N2UEJGZHclM0QlM0Q; _sp_id.8ca5=4c19c5a3-4e70-4727-8336-a0f2c5fcb7ae.1636501343.4.1636641025.1636578697.5724cbb4-37af-443c-a22c-26362577d75b',
    'if-none-match': 'W/^\\^b863d05a1913cbe8d162cdce62ebbf0d^\\^',
}
name= []
model= []
year= []
price= []
mileage= []
city= []
state= []
dealer_name= []


for i in range(1,17):
    params = (
    ('make', 'Tesla'),
    ('location', 'New^%%5E20York,^%%5E20NY'),
    ('latitude', '40.7127753'),
    ('longitude', '-74.0059728'),
    ('radius', '50'),
    ('page', str(i)),
    )
    
    # response variable for the get request
    
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    # json object
    results_json = response.json()
    #result items (20 items for page)
    results_items=results_json['search_results']
    
    for result in results_items:
        name.append(result['make'])
        model.append(result['model'])
        year.append(result['year'])
        price.append(result['price'])
        mileage.append(result['mileage'])
        city.append(result['city'])
        state.append(result['state'])
        dealer_name.append(result['dealer_name'])

# %%
len(name)
# Out:
# 320

# %%
cars_multipl_df= pd.DataFrame({'Name':name,'Model':model,'Year':year,'City':city,'State':state,'Dealer_name':dealer_name,'Mileage':mileage,'Price':price})

# %%
cars_multipl_df
# Out:
#       Name    Model  Year            City State  \
# 0    Tesla  Model S  2014           Bronx    NY
# 1    Tesla  Model S  2014      Somerville    NJ
# 2    Tesla  Model X  2018    White Plains    NY
# 3    Tesla  Model 3  2020       Elizabeth    NJ
# 4    Tesla  Model S  2017          Totowa    NJ
# ..     ...      ...   ...             ...   ...
# 315  Tesla  Model 3  2021          Irvine    CA
# 316  Tesla  Model 3  2019         Fremont    CA
# 317  Tesla  Model 3  2019          Avenel    NJ
# 318  Tesla  Model 3  2020  Middle Village    NY
# 319  Tesla  Model 3  2019      Great Neck    NY
#
#                                            Dealer_name       Mileage    Price
# 0                                            26 Motors  56,461 Miles  $33,950
# 1                                             AMG Auto  66,843 Miles  $42,900
# 2                                        Northeast Kia  20,046 Miles  $84,295
# ...

# %%
cars_multipl_df.to_excel('teslaCarsMultiplPage.xlsx',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# C:\Users\ANASSE~1\AppData\Local\Temp/ipykernel_13264/1912081483.py in <module>
# ----> 1 cars_multipl_df.to_excel('teslaCarsMultiplPage.xlsx',index=False)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2282             inf_rep=inf_rep,
#    2283         )
# -> 2284         formatter.write(
#    2285             excel_writer,
#    2286             sheet_name=sheet_name,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
# ...
